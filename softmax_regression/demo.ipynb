# %%
from soft_reg import SoftmaxRegression
from preprocessing_data import train_images, train_labels, test_images, test_labels
# Out:
# (60000, 28, 28)

# %%
model = SoftmaxRegression(n_classes=10)
model.fit(train_images, train_labels)
# Out:
# Iteration 100/1000, Loss: 1.5591
# Iteration 200/1000, Loss: 1.1960
# Iteration 300/1000, Loss: 1.0006
# Iteration 400/1000, Loss: 0.8809
# Iteration 500/1000, Loss: 0.8001
# Iteration 600/1000, Loss: 0.7418
# Iteration 700/1000, Loss: 0.6974
# Iteration 800/1000, Loss: 0.6624
# Iteration 900/1000, Loss: 0.6340
# Iteration 1000/1000, Loss: 0.6104

# %%
y_pred = model.predict(test_images)

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score

print("Accuracy:", accuracy_score(test_labels, y_pred))
print("Precision:", precision_score(test_labels, y_pred, average="macro"))
print("Recall:", recall_score(test_labels, y_pred, average="macro"))
print("F1 Score:", f1_score(test_labels, y_pred, average="macro"))
# Out:
# Accuracy: 0.8708
# Precision: 0.870395520442593
# Recall: 0.8685678653854747
# F1 Score: 0.8683802229172676
